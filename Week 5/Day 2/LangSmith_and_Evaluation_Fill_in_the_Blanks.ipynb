# %% [markdown]
# # LangSmith and Evaluation Overview with AI Makerspace
#
# Today we'll be looking at an amazing tool:
#
# [LangSmith](https://docs.smith.langchain.com/)!
#
# This tool will help us monitor, test, debug, and evaluate our LangChain applications - and more!
#
# We'll also be looking at a few Advanced Retrieval techniques along the way - and evaluate it using LangSmith!
#
# ✋BREAKOUT ROOM #1:
# - Task 1: Dependencies and OpenAI API Key
# - Task 2: Basic RAG Chain
# - Task 3: Setting Up LangSmith
# - Task 4: Examining the Trace in LangSmith!
# - Task 5: Create Testing Dataset
#
# ✋BREAKOUT ROOM #2:
# - Task 1: Parent Document Retriever
# - Task 2: Ensemble Retriever

# %% [markdown]
# ## Task 1: Dependencies and OpenAI API Key
#
# We'll be using OpenAI's suite of models today to help us generate and embed our documents for a simple RAG system built on top of LangChain's blogs!

# %%
# !pip install langchain_core langchain_openai langchain_community langchain-qdrant qdrant-client langsmith openai tiktoken cohere lxml -qU
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# wandb 0.16.6 requires protobuf!=4.21.0,<5,>=3.19.0; python_version > "3.9" and sys_platform == "linux", but you have protobuf 5.27.2 which is incompatible.
# opentelemetry-proto 1.25.0 requires protobuf<5.0,>=3.19, but you have protobuf 5.27.2 which is incompatible.
#
# [notice] A new release of pip is available: 23.1.2 -> 24.1
# [notice] To update, run: pip install --upgrade pip

# %%
import os
from dotenv import find_dotenv, dotenv_values

keys = list(dotenv_values(find_dotenv('.env')).items())
os.environ['OPENAI_API_KEY'] = keys[0][1]

# %% [markdown]
# ## Task 2: Basic RAG Chain
#
# Now we'll set up our basic RAG chain, first up we need a model!

# %% [markdown]
# ### OpenAI Model
#
#
# We'll use OpenAI's `gpt-3.5-turbo` model to ensure we can use a stronger model for decent evaluation later!
#
# Notice that we can tag our resources - this will help us be able to keep track of which resources were used where later on!

# %%
from langchain_openai.chat_models import ChatOpenAI

base_llm = ChatOpenAI(
    model="gpt-4o",
    tags=["base_llm"]
)

# %% [markdown]
# #### Asyncio Bug Handling
#
# This is necessary for Colab.

# %%
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# ### SiteMap Loader
#
# We'll use a SiteMapLoader to scrape the LangChain blogs.

# %%
from langchain.document_loaders import SitemapLoader

documents = SitemapLoader(web_path="https://blog.langchain.dev/sitemap-posts.xml").load()
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# Fetching pages: 100%|##########| 221/221 [00:12<00:00, 17.12it/s]

# %%
documents[0].metadata["source"]
# Out:
# 'https://blog.langchain.dev/what-is-an-agent/'

# %% [markdown]
# ### RecursiveCharacterTextSplitter
#
# We're going to use a relatively naive text splitting strategy today!

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

split_documents = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    chunk_size = 500,
    chunk_overlap = 20
).split_documents(documents)

# %%
len(split_documents)
# Out:
# 1548

# %% [markdown]
# ### Embeddings
#
# We'll be leveraging OpenAI's [text-embedding-3-small](https://openai.com/index/new-embedding-models-and-api-updates/) today!

# %%
from langchain_openai.embeddings import OpenAIEmbeddings

base_embeddings_model = OpenAIEmbeddings(model="text-embedding-3-small")

# %% [markdown]
# ### Qdrant VectorStore Retriever
#
# Now we can use a Qdrant VectorStore to embed and store our documents and then convert it to a retriever so it can be used in our chain!

# %%
from langchain_qdrant import Qdrant

vectorstore = Qdrant.from_documents(
    split_documents,
    base_embeddings_model,
    location=":memory:",
    collection_name="langchainblogs")

# %%
base_retriever = vectorstore.as_retriever()

# %% [markdown]
# ### Prompt Template
#
# All we have left is a prompt template, which we'll create here!

# %%
from langchain.prompts import ChatPromptTemplate

base_rag_prompt_template = """\
Using the provided context, please answer the user's question. If you don't know the answer based on the context, say you don't know.

Context:
{context}

Question:
{question}
"""

base_rag_prompt = ChatPromptTemplate.from_template(base_rag_prompt_template)

# %% [markdown]
# ### LCEL Chain
#
# Now that we have:
#
# - Embeddings Model
# - Generation Model
# - Retriever
# - Prompt
#
# We're ready to build our LCEL chain!
#
# Keep in mind that we're returning our source documents with our queries - while this isn't necessary, it's a great thing to get into the habit of doing.

# %%
from operator import itemgetter
from langchain_core.runnables import RunnablePassthrough, RunnableParallel
from langchain.schema import StrOutputParser

base_rag_chain = (
    # INVOKE CHAIN WITH: {"question" : "<<SOME USER QUESTION>>"}
    # "question" : populated by getting the value of the "question" key
    # "context"  : populated by getting the value of the "question" key and chaining it into the base_retriever
    {"context": itemgetter("question") | base_retriever, "question": itemgetter("question")}
    # "context"  : is assigned to a RunnablePassthrough object (will not be called or considered in the next step)
    #              by getting the value of the "context" key from the previous step
    | RunnablePassthrough.assign(context=itemgetter("context"))
    # "response" : the "context" and "question" values are used to format our prompt object and then piped
    #              into the LLM and stored in a key called "response"
    # "context"  : populated by getting the value of the "context" key from the previous step
    | {"response": base_rag_prompt | base_llm | StrOutputParser(), "context": itemgetter("context")}
)

# %% [markdown]
# Let's test it out!

# %%
base_rag_chain.invoke({"question" : "What is a good way to evaluate agents?"})["response"]
# Out:
# "A good way to evaluate agents is through benchmarking their ability to effectively use tools to accomplish tasks. This involves designing tasks that test capabilities such as planning, task decomposition, function calling, and the ability to override pre-trained biases. Specific benchmarks can help measure function calling performance and overall agentic behavior. For instance, the provided context mentions test environments for tasks like the Relational Data task, which has been used to gauge model performance. It's also important to validate the LLM on the behavior patterns needed for the specific application before deploying it.\n\nFor example, the context describes evaluating agents on tasks that are prerequisites for common workflows and notes that even the best models can fail over longer trajectories or complex tasks. Additionally, performance metrics and error bars, like those mentioned for models such as GPT-4 and Claude-2.1, can provide insights into reliability and areas for improvement.\n\nOverall, assessing planning, tool use, and the ability to generalize across tasks can be key indicators of an agent's effectiveness."

# %% [markdown]
# ## Task 3: Setting Up LangSmith
#
# Now that we have a chain - we're ready to get started with LangSmith!
#
# We're going to go ahead and use the following `env` variables to get our Colab notebook set up to start reporting.
#
# If all you needed was simple monitoring - this is all you would need to do!

# %%
from uuid import uuid4

unique_id = uuid4().hex[0:8]

os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = f"LangSmith - {unique_id}"

# %% [markdown]
# ### LangSmith API
#
# In order to use LangSmith - you will need a beta key, you can join the queue through the `Beta Sign Up` button on LangSmith's homepage!
#
# Join [here](https://www.langchain.com/langsmith)

# %%
keys = list(dotenv_values(find_dotenv('.env')).items())
os.environ['LANGCHAIN_API_KEY'] = keys[1][1]

# %% [markdown]
# Let's test our our first generation!

# %%
base_rag_chain.invoke({"question" : "What is LangSmith?"}, {"tags" : ["Demo Run"]})['response']
# Out:
# 'LangSmith is a unified platform designed to debug, test, evaluate, and monitor LLM (Large Language Model) applications. It offers features like utilizing existing datasets or creating new ones, running them against your chains, and providing visual feedback on outputs and accuracy metrics. It is usable with or without LangChain and aims to streamline the development and management of LLM applications. LangSmith also includes capabilities for real-time monitoring and collaboration through its recently launched Hub.'

# %% [markdown]
# ## Task 4: Examining the Trace in LangSmith!
#
# Head on over to your LangSmith web UI to check out how the trace looks in LangSmith!

# %% [markdown]
# #### 🏗️ Activity #1:
#
# Include a screenshot of your trace and explain what it means.

# %% [markdown]
# ![image](screenshots/trace.png)
#
# This trace shows the history of the query, I.E. the model input, the referenced material, and any additional metadata associated with the api call through the LangChain invocation.

# %% [markdown]
# ## Task 5: Create Testing Dataset
#
# Now we can create a dataset using some user defined questions, and providing the retrieved context as a "ground truth" context.
#
# > NOTE: There are many different ways you can approach this specific task - generating ground truth answers with AI, using human experts to generate golden datasets, and more!

# %% [markdown]
# ### Synthetic Data Generation (SDG)
#
# In order to full test our RAG chain, and the various modifications we'll be using in the following notebook, we'll need to create a small synthetic dataset that is relevant to our task!
#
# Let's start by generating a series of questions - which begins with a simple model definition!
#
# > NOTE: We're going to be using a purposefully simplified datagen pipeline as an example today - but you could leverage the RAGAS SDG pipeline just as easily.

# %%
question_model = ChatOpenAI(model="gpt-4o")

# %% [markdown]
# Next up, we'll create some novel chunks from our source data!

# %%
sdg_documents = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    chunk_size = 1000,
    chunk_overlap = 20
).split_documents(documents)

# %% [markdown]
# Now, let's ask some questions that could be answered from the provided chunks!

# %%
question_prompt_template = """\
You are a University Professor creating questions for an exam. You must create a question for a given piece of context.

The question must be answerable only using the provided context.

Avoid creating questions that are ambiguous or vague. They should be specifically related to the context.

Your output must only be the question.

Context:
{context}
"""

question_prompt = ChatPromptTemplate.from_template(question_prompt_template)

# %%
question_chain = question_prompt | question_model

# %% [markdown]
# Now we can loop through a subset of our context chunks and create question/context pairs!

# %%
from tqdm import tqdm
import json

question_context_pairs = []

for idx in tqdm(range(0, len(sdg_documents), 40)):
  question = question_chain.invoke({"context" : sdg_documents[idx].page_content})
  question_context_pairs.append({"question" : question.content, "context" : sdg_documents[idx].page_content, "idx" : idx})
# Out:
# 100%|██████████| 23/23 [00:16<00:00,  1.42it/s]

# %%
question_context_pairs[0]
# Out:
# {'question': 'What is the main topic introduced by Harrison Chase in his 4-minute read article dated June 28, 2024?',
#  'context': 'What is an agent?\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to content\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAll Posts\n\n\n\n\nRelease Notes\n\n\n\n\nCase Studies\n\n\n\n\nIn the Loop\n\n\n\n\nLangChain\n\n\n\n\nDocs\n\n\n\n\n\nSign in\nSubscribe\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nWhat is an agent?\nIntroducing a new series of musings on AI agents.\n\nHarrison Chase\n4 min read\nJun 28, 2024',
#  'idx': 0}

# %% [markdown]
# We'll repeat this process for answers!

# %%
answer_prompt_template = """\
You are a University Professor creating an exam. You must create a answer for a given piece of context and question.

The answer must only rely on the provided context.

Your output must only be the answer.

Context:
{context}
"""

answer_prompt = ChatPromptTemplate.from_template(answer_prompt_template)

# %%
answer_chain = answer_prompt | question_model

# %%
for question_context_pair in tqdm(question_context_pairs):
  question_context_pair["answer"] = answer_chain.invoke({"question" : question_context_pair["question"], "context" : question_context_pair["context"]}).content
# Out:
# 100%|██████████| 23/23 [00:23<00:00,  1.01s/it]

# %%
question_context_pairs[0]
# Out:
# {'question': 'What is the main topic introduced by Harrison Chase in his 4-minute read article dated June 28, 2024?',
#  'context': 'What is an agent?\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to content\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAll Posts\n\n\n\n\nRelease Notes\n\n\n\n\nCase Studies\n\n\n\n\nIn the Loop\n\n\n\n\nLangChain\n\n\n\n\nDocs\n\n\n\n\n\nSign in\nSubscribe\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nWhat is an agent?\nIntroducing a new series of musings on AI agents.\n\nHarrison Chase\n4 min read\nJun 28, 2024',
#  'idx': 0,
#  'answer': 'An agent refers to an AI entity that performs tasks or makes decisions based on given inputs.'}

# %% [markdown]
# Now we can set up our LangSmith client - and we'll add the above created dataset to our LangSmith instance!
#
# > NOTE: Read more about this process [here](https://docs.smith.langchain.com/old/evaluation/faq/manage-datasets#create-from-list-of-values)

# %%
from langsmith import Client

client = Client()

dataset_name = "langsmith-demo-dataset-v1"

dataset = client.create_dataset(
    dataset_name=dataset_name, description="LangChain Blog Test Questions"
)

for triplet in question_context_pairs:
  client.create_example(
      inputs={"question" : triplet["question"]},
      outputs={"answer" : triplet["answer"]},
      dataset_id=dataset.id
  )

# %% [markdown]
# ### Evaluation
#
# Now we can run the evaluation!
#
# We'll need to start by preparing some custom data preparation functions to ensure our chain works with the expected inputs/outputs from the `evaluate` process in LangSmith.
#
# > NOTE: More reading on this available [here](https://docs.smith.langchain.com/how_to_guides/evaluation/evaluate_llm_application#evaluate-a-langchain-runnable)

# %%
def prepare_data_ref(run, example):
  return {
      "prediction" : run.outputs["response"],
      "reference" : example.outputs["answer"],
      "input" : example.inputs["question"]
  }

def prepare_data_noref(run, example):
  return {
      "prediction" : run.outputs["response"],
      "input" : example.inputs["question"]
  }

# %% [markdown]
# We'll be using a few custom evaluators to evaluate our pipeline, as well as a few "built in" methods!
#
# Check out the built-ins [here](https://docs.smith.langchain.com/reference/sdk_reference/langchain_evaluators)!

# %%
from langsmith.evaluation import LangChainStringEvaluator, evaluate

cot_qa_evaluator = LangChainStringEvaluator("cot_qa", prepare_data=prepare_data_ref)

unlabeled_dopeness_evaluator = LangChainStringEvaluator(
    "criteria",
    config={
        "criteria" : {
            "dopeness" : "Is the answer to the question dope, meaning cool - awesome - and legit?"
        }
    },
    prepare_data=prepare_data_noref
)

labeled_score_evaluator = LangChainStringEvaluator(
    "labeled_score_string",
    config={
        "criteria": {
            "accuracy": "Is the generated answer the same as the reference answer?"
        },
    },
    prepare_data=prepare_data_ref
)

unlabeled_coherence_evaluator = LangChainStringEvaluator("criteria", config={ "criteria": "coherence"}, prepare_data=prepare_data_noref)
labeled_relevance_evaluator = LangChainStringEvaluator("criteria", config={ "criteria": "relevance"}, prepare_data=prepare_data_ref)


base_rag_results = evaluate(
    base_rag_chain.invoke,
    data=dataset_name,
    evaluators=[
        cot_qa_evaluator,
        unlabeled_dopeness_evaluator,
        labeled_score_evaluator,
        unlabeled_coherence_evaluator,
        labeled_relevance_evaluator
        ],
    experiment_prefix="Base RAG Evaluation"
)
# Out:
# View the evaluation results for experiment: 'Base RAG Evaluation-77fad27c' at:
# https://smith.langchain.com/o/075e5472-35f7-58d2-a3bd-164944ffb76c/datasets/05a5aaa5-58d9-496c-a24b-86f2c481b525/compare?selectedSessions=2a0880f0-c3e8-4271-9450-85ad6d9df3e2
# 0it [00:00, ?it/s]
# Error running target function: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 30000, Used 28482, Requested 2622. Please try again in 2.208s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running target function: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 30000, Used 28530, Requested 1503. Please try again in 66ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running target function: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 30000, Used 28271, Requested 1771. Please try again in 84ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running target function: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 30000, Used 28131, Requested 2008. Please try again in 278ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running target function: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 30000, Used 29843, Requested 2226. Please try again in 4.138s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 674e0d56-ace1-4769-af9c-79f7eef29d1f: KeyError('response')
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 255, in evaluate
#     else self._prepare_data(run, example)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_78689/3523963876.py", line 3, in prepare_data_ref
#     "prediction" : run.outputs["response"],
#                    ~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'response'
# Error running evaluator <DynamicRunEvaluator evaluate> on run 03b17772-d4e4-4bf1-976b-e0a04185e5c0: KeyError('response')
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 255, in evaluate
#     else self._prepare_data(run, example)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_78689/3523963876.py", line 3, in prepare_data_ref
#     "prediction" : run.outputs["response"],
#                    ~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'response'
# Error running evaluator <DynamicRunEvaluator evaluate> on run 669003eb-9c9c-4c2f-a449-2567dfc7448c: KeyError('response')
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 255, in evaluate
#     else self._prepare_data(run, example)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_78689/3523963876.py", line 3, in prepare_data_ref
#     "prediction" : run.outputs["response"],
#                    ~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'response'
# Error running evaluator <DynamicRunEvaluator evaluate> on run 924a3313-063a-45b8-8ba7-0aa6fe511417: KeyError('response')
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 255, in evaluate
#     else self._prepare_data(run, example)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_78689/3523963876.py", line 3, in prepare_data_ref
#     "prediction" : run.outputs["response"],
#                    ~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'response'
# Error running evaluator <DynamicRunEvaluator evaluate> on run 35dc827e-a411-4050-b55e-75493bf484cd: KeyError('response')
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 255, in evaluate
#     else self._prepare_data(run, example)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_78689/3523963876.py", line 3, in prepare_data_ref
#     "prediction" : run.outputs["response"],
#                    ~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'response'
# Error running evaluator <DynamicRunEvaluator evaluate> on run 674e0d56-ace1-4769-af9c-79f7eef29d1f: KeyError('response')
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 255, in evaluate
#     else self._prepare_data(run, example)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_78689/3523963876.py", line 10, in prepare_data_noref
#     "prediction" : run.outputs["response"],
#                    ~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'response'
# Error running evaluator <DynamicRunEvaluator evaluate> on run 03b17772-d4e4-4bf1-976b-e0a04185e5c0: KeyError('response')
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 255, in evaluate
#     else self._prepare_data(run, example)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_78689/3523963876.py", line 10, in prepare_data_noref
#     "prediction" : run.outputs["response"],
#                    ~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'response'
# Error running evaluator <DynamicRunEvaluator evaluate> on run 669003eb-9c9c-4c2f-a449-2567dfc7448c: KeyError('response')
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 255, in evaluate
#     else self._prepare_data(run, example)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_78689/3523963876.py", line 10, in prepare_data_noref
#     "prediction" : run.outputs["response"],
#                    ~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'response'
# Error running evaluator <DynamicRunEvaluator evaluate> on run 35dc827e-a411-4050-b55e-75493bf484cd: KeyError('response')
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 255, in evaluate
#     else self._prepare_data(run, example)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_78689/3523963876.py", line 10, in prepare_data_noref
#     "prediction" : run.outputs["response"],
#                    ~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'response'
# Error running evaluator <DynamicRunEvaluator evaluate> on run 924a3313-063a-45b8-8ba7-0aa6fe511417: KeyError('response')
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 255, in evaluate
#     else self._prepare_data(run, example)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_78689/3523963876.py", line 10, in prepare_data_noref
#     "prediction" : run.outputs["response"],
#                    ~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'response'
# Error running evaluator <DynamicRunEvaluator evaluate> on run 674e0d56-ace1-4769-af9c-79f7eef29d1f: KeyError('response')
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 255, in evaluate
#     else self._prepare_data(run, example)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_78689/3523963876.py", line 3, in prepare_data_ref
#     "prediction" : run.outputs["response"],
#                    ~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'response'
# Error running evaluator <DynamicRunEvaluator evaluate> on run 03b17772-d4e4-4bf1-976b-e0a04185e5c0: KeyError('response')
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 255, in evaluate
#     else self._prepare_data(run, example)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_78689/3523963876.py", line 3, in prepare_data_ref
#     "prediction" : run.outputs["response"],
#                    ~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'response'
# Error running evaluator <DynamicRunEvaluator evaluate> on run 669003eb-9c9c-4c2f-a449-2567dfc7448c: KeyError('response')
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 255, in evaluate
#     else self._prepare_data(run, example)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_78689/3523963876.py", line 3, in prepare_data_ref
#     "prediction" : run.outputs["response"],
#                    ~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'response'
# Error running evaluator <DynamicRunEvaluator evaluate> on run 924a3313-063a-45b8-8ba7-0aa6fe511417: KeyError('response')
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 255, in evaluate
#     else self._prepare_data(run, example)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_78689/3523963876.py", line 3, in prepare_data_ref
#     "prediction" : run.outputs["response"],
#                    ~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'response'
# Error running evaluator <DynamicRunEvaluator evaluate> on run 35dc827e-a411-4050-b55e-75493bf484cd: KeyError('response')
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 255, in evaluate
#     else self._prepare_data(run, example)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_78689/3523963876.py", line 3, in prepare_data_ref
#     "prediction" : run.outputs["response"],
#                    ~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'response'
# Error running evaluator <DynamicRunEvaluator evaluate> on run 674e0d56-ace1-4769-af9c-79f7eef29d1f: KeyError('response')
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 255, in evaluate
#     else self._prepare_data(run, example)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_78689/3523963876.py", line 10, in prepare_data_noref
#     "prediction" : run.outputs["response"],
#                    ~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'response'
# Error running evaluator <DynamicRunEvaluator evaluate> on run 669003eb-9c9c-4c2f-a449-2567dfc7448c: KeyError('response')
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 255, in evaluate
#     else self._prepare_data(run, example)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_78689/3523963876.py", line 10, in prepare_data_noref
#     "prediction" : run.outputs["response"],
#                    ~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'response'
# Error running evaluator <DynamicRunEvaluator evaluate> on run 03b17772-d4e4-4bf1-976b-e0a04185e5c0: KeyError('response')
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 255, in evaluate
#     else self._prepare_data(run, example)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_78689/3523963876.py", line 10, in prepare_data_noref
#     "prediction" : run.outputs["response"],
#                    ~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'response'
# Error running evaluator <DynamicRunEvaluator evaluate> on run 924a3313-063a-45b8-8ba7-0aa6fe511417: KeyError('response')
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 255, in evaluate
#     else self._prepare_data(run, example)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_78689/3523963876.py", line 10, in prepare_data_noref
#     "prediction" : run.outputs["response"],
#                    ~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'response'
# Error running evaluator <DynamicRunEvaluator evaluate> on run 35dc827e-a411-4050-b55e-75493bf484cd: KeyError('response')
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 255, in evaluate
#     else self._prepare_data(run, example)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_78689/3523963876.py", line 10, in prepare_data_noref
#     "prediction" : run.outputs["response"],
#                    ~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'response'
# Error running evaluator <DynamicRunEvaluator evaluate> on run 674e0d56-ace1-4769-af9c-79f7eef29d1f: KeyError('response')
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 255, in evaluate
#     else self._prepare_data(run, example)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_78689/3523963876.py", line 3, in prepare_data_ref
#     "prediction" : run.outputs["response"],
#                    ~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'response'
# Error running evaluator <DynamicRunEvaluator evaluate> on run 669003eb-9c9c-4c2f-a449-2567dfc7448c: KeyError('response')
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 255, in evaluate
#     else self._prepare_data(run, example)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_78689/3523963876.py", line 3, in prepare_data_ref
#     "prediction" : run.outputs["response"],
#                    ~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'response'
# Error running evaluator <DynamicRunEvaluator evaluate> on run 924a3313-063a-45b8-8ba7-0aa6fe511417: KeyError('response')
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 255, in evaluate
#     else self._prepare_data(run, example)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_78689/3523963876.py", line 3, in prepare_data_ref
#     "prediction" : run.outputs["response"],
#                    ~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'response'
# Error running evaluator <DynamicRunEvaluator evaluate> on run 03b17772-d4e4-4bf1-976b-e0a04185e5c0: KeyError('response')
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 255, in evaluate
#     else self._prepare_data(run, example)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_78689/3523963876.py", line 3, in prepare_data_ref
#     "prediction" : run.outputs["response"],
#                    ~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'response'
# Error running evaluator <DynamicRunEvaluator evaluate> on run 35dc827e-a411-4050-b55e-75493bf484cd: KeyError('response')
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 255, in evaluate
#     else self._prepare_data(run, example)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_78689/3523963876.py", line 3, in prepare_data_ref
#     "prediction" : run.outputs["response"],
#                    ~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'response'
# Error running evaluator <DynamicRunEvaluator evaluate> on run e7fd2b6b-bb72-4cd2-bc42-b1daba811948: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9853, Requested 479. Please try again in 1.992s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9853, Requested 479. Please try again in 1.992s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 76b277a7-60b0-45dd-a734-fa1a0dd777fb: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9767, Requested 564. Please try again in 1.985s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
# ...
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9700, Requested 561. Please try again in 1.566s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# /home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/schema.py:128: UserWarning: Ignoring reference in CriteriaEvalChain, as it is not expected.
# To use references, use the labeled_criteria instead.
#   warn(self._skip_reference_warning)
# Error running evaluator <DynamicRunEvaluator evaluate> on run 44e38622-13f7-418c-b376-08cad0d2127e: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9686, Requested 330. Please try again in 96ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9686, Requested 330. Please try again in 96ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 76b277a7-60b0-45dd-a734-fa1a0dd777fb: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9955, Requested 561. Please try again in 3.096s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9955, Requested 561. Please try again in 3.096s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}

# %% [markdown]
# ## Testing Other Retrievers
#
# Now we can test our how changing our Retriever impacts our LangSmith evaluation!
#
# We'll build this simple qa_chain factory to create standardized qa_chains where the only different component will be the retriever.

# %%
def create_qa_chain(retriever):
  primary_qa_llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)
  created_qa_chain = (
    {"context": itemgetter("question") | retriever,
     "question": itemgetter("question")
    }
    | RunnablePassthrough.assign(
        context=itemgetter("context")
      )
    | {
         "response": base_rag_prompt | primary_qa_llm,
         "context": itemgetter("context"),
      }
  )
  return created_qa_chain

# %% [markdown]
# ### Task 1: Parent Document Retriever
#
# One of the easier ways we can imagine improving a retriever is to embed our documents into small chunks, and then retrieve a significant amount of additional context that "surrounds" the found context.
#
# You can read more about this method [here](https://python.langchain.com/docs/modules/data_connection/retrievers/parent_document_retriever)!
#
# The basic outline of this retrieval method is as follows:
#
# 1. Obtain User Question
# 2. Retrieve child documents using Dense Vector Retrieval
# 3. Merge the child documents based on their parents. If they have the same parents - they become merged.
# 4. Replace the child documents with their respective parent documents from an in-memory-store.
# 5. Use the parent documents to augment generation.

# %%
from langchain.retrievers import ParentDocumentRetriever
from langchain.storage import InMemoryStore
from qdrant_client import QdrantClient
from qdrant_client.models import Distance, VectorParams

client = QdrantClient(":memory:")
client.create_collection(
    collection_name="split_parents",
    vectors_config=VectorParams(size=1536, distance=Distance.COSINE),
)

vectorstore = Qdrant(client, collection_name="split_parents", embeddings=base_embeddings_model)

store = InMemoryStore()

# %%
parent_document_retriever = ParentDocumentRetriever(
    vectorstore=vectorstore,
    docstore=store,
    child_splitter=RecursiveCharacterTextSplitter(chunk_size=500),
    parent_splitter=RecursiveCharacterTextSplitter(chunk_size=2500)
)

# %%
parent_document_retriever.add_documents(documents)

# %% [markdown]
# Let's create, test, and then evaluate our new chain!

# %%
parent_document_retriever_qa_chain = create_qa_chain(parent_document_retriever)

# %%
parent_document_retriever_qa_chain.invoke({"question" : "What is RAG?"})["response"].content
# Out:
# 'RAG stands for Retrieval Augmented Generation. It is a paradigm in LLM application development that involves connecting Large Language Models (LLMs) to external data sources to dynamically retrieve relevant information for generating responses.'

# %% [markdown]
# #### Evaluating the Parent Document Retrieval Pipeline
#
# Now that we've created a new retriever - let's try evaluating it on the same dataset!

# %%
pdr_rag_results = evaluate(
    parent_document_retriever_qa_chain.invoke,
    data=dataset_name,
    evaluators=[
        cot_qa_evaluator,
        unlabeled_dopeness_evaluator,
        labeled_score_evaluator,
        unlabeled_coherence_evaluator,
        labeled_relevance_evaluator
        ],
    experiment_prefix="Parent Document Retrieval RAG Evaluation"
)
# Out:
# View the evaluation results for experiment: 'Parent Document Retrieval RAG Evaluation-ffbdb8b1' at:
# https://smith.langchain.com/o/075e5472-35f7-58d2-a3bd-164944ffb76c/datasets/05a5aaa5-58d9-496c-a24b-86f2c481b525/compare?selectedSessions=2ee007b3-aeee-4a70-a73f-14c2cc147a68
# 0it [00:00, ?it/s]
# Error running evaluator <DynamicRunEvaluator evaluate> on run e2fb1f42-5a19-4bdb-a0c8-59b646b6e2bd: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9846, Requested 468. Please try again in 1.883s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/qa/eval_chain.py", line 307, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9846, Requested 468. Please try again in 1.883s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 856d55e7-2722-4628-a283-b39a73d90e7d: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9862, Requested 301. Please try again in 977ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9862, Requested 301. Please try again in 977ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run c687880b-6bf7-4aa0-a0c0-1af135c77f04: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9851, Requested 348. Please try again in 1.194s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9851, Requested 348. Please try again in 1.194s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 1efed747-ffd8-4a7e-b67c-46153e2228db: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9853, Requested 340. Please try again in 1.158s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9853, Requested 340. Please try again in 1.158s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 3f83fb27-eda0-4dbb-8242-d0df584db531: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9926, Requested 349. Please try again in 1.65s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9926, Requested 349. Please try again in 1.65s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 557c5f08-5731-4088-81a7-3532dde932a1: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9873, Requested 347. Please try again in 1.32s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9873, Requested 347. Please try again in 1.32s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run c4dc2a1c-8f19-4250-b36c-484b7a9b1a04: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9872, Requested 349. Please try again in 1.326s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# ...
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9927, Requested 383. Please try again in 1.86s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 4c7239c5-e346-4ebb-8063-b225b05b4b78: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9926, Requested 395. Please try again in 1.925s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9926, Requested 395. Please try again in 1.925s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run c0b917c4-8d7f-45e3-9b9c-9b4cd20b86df: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9867, Requested 459. Please try again in 1.955s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9867, Requested 459. Please try again in 1.955s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}

# %% [markdown]
# ### Task 2: Ensemble Retrieval
#
# Next let's look at ensemble retrieval!
#
# You can read more about this [here](https://python.langchain.com/docs/modules/data_connection/retrievers/ensemble)!
#
# The basic idea is as follows:
#
# 1. Obtain User Question
# 2. Hit the Retriever Pair
#     - Retrieve Documents with BM25 Sparse Vector Retrieval
#     - Retrieve Documents with Dense Vector Retrieval Method
# 3. Collect and "fuse" the retrieved docs based on their weighting using the [Reciprocal Rank Fusion](https://plg.uwaterloo.ca/~gvcormac/cormacksigir09-rrf.pdf) algorithm into a single ranked list.
# 4. Use those documents to augment our generation.
#
# Ensure your `weights` list - the relative weighting of each retriever - sums to 1!

# %%
# !pip install -q -U rank_bm25
# Out:
# [notice] A new release of pip is available: 23.1.2 -> 24.1
# [notice] To update, run: pip install --upgrade pip

# %%
from langchain.retrievers import BM25Retriever, EnsembleRetriever

text_splitter = RecursiveCharacterTextSplitter(chunk_size=450, chunk_overlap=75)
split_documents = text_splitter.split_documents(documents)

bm25_retriever = BM25Retriever.from_documents(split_documents)
bm25_retriever.k = 2

embedding = OpenAIEmbeddings()
vectorstore = Qdrant.from_documents(split_documents, embedding, location=":memory:")
qdrant_retriever = vectorstore.as_retriever(search_kwargs={"k": 3})

ensemble_retriever = EnsembleRetriever(
    retrievers=[
        bm25_retriever,
        qdrant_retriever
    ],
    weights=[
        0.5,
        0.5
    ])

# %%
ensemble_retriever_qa_chain = create_qa_chain(ensemble_retriever)

# %%
ensemble_retriever_qa_chain.invoke({"question" : "What is RAG?"})["response"].content
# Out:
# 'RAG stands for Retrieval Augmented Generation, which is a central paradigm in LLM application development that connects LLMs to external data sources to address the lack of recent or private information in the models.'

# %%
pdr_rag_results = evaluate(
    ensemble_retriever_qa_chain.invoke,
    data=dataset_name,
    evaluators=[
        cot_qa_evaluator,
        unlabeled_dopeness_evaluator,
        labeled_score_evaluator,
        unlabeled_coherence_evaluator,
        labeled_relevance_evaluator
        ],
    experiment_prefix="Hybrid Retrieval RAG Evaluation"
)
# Out:
# View the evaluation results for experiment: 'Hybrid Retrieval RAG Evaluation-a8c50672' at:
# https://smith.langchain.com/o/075e5472-35f7-58d2-a3bd-164944ffb76c/datasets/05a5aaa5-58d9-496c-a24b-86f2c481b525/compare?selectedSessions=97117f3e-86f5-42a9-80b2-1d5d6848aefe
# 0it [00:00, ?it/s]
# Error running evaluator <DynamicRunEvaluator evaluate> on run 72932717-25c9-43db-9d79-149ee3558449: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9944, Requested 434. Please try again in 2.268s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/qa/eval_chain.py", line 307, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9944, Requested 434. Please try again in 2.268s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 17eceef9-0c05-4cec-ac07-71fcea1f0551: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9875, Requested 298. Please try again in 1.038s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9875, Requested 298. Please try again in 1.038s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run d1ae4801-c2f0-41e7-a158-982f8ff8c759: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9934, Requested 339. Please try again in 1.638s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9934, Requested 339. Please try again in 1.638s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 2ed4ddd2-9a2b-416d-8477-372a6bc6e1d3: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9937, Requested 338. Please try again in 1.65s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9937, Requested 338. Please try again in 1.65s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run cfac88e3-81ac-49a9-9054-b6ac5bc33522: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9932, Requested 343. Please try again in 1.65s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9932, Requested 343. Please try again in 1.65s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 2ad62446-b512-4074-bd77-946b8c04ea36: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9917, Requested 353. Please try again in 1.62s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9917, Requested 353. Please try again in 1.62s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 81b550bf-a082-4c2e-b48d-f826b5e870d4: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9905, Requested 348. Please try again in 1.518s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# ...
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9892, Requested 427. Please try again in 1.913s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run cf732d80-50c6-45b0-afcd-ab975d7700c1: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9891, Requested 434. Please try again in 1.95s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9891, Requested 434. Please try again in 1.95s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 97821015-75f4-458f-9082-3db0659640dd: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9923, Requested 486. Please try again in 2.454s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/rcwaterman/AI_Makerspace/AI-Engineering-3/venv/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-Q1j5PXcCb8hyDYWrex9bHWhs on tokens per min (TPM): Limit 10000, Used 9923, Requested 486. Please try again in 2.454s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}

# %% [markdown]
# #### ❓Question #1:
#
# What conclusions can you draw about the above results?
#
# Describe in your own words what the metrics are expressing.
#
# ![image](screenshots/metrics.png)
#
# The metrics in the screenshot, above, define the coherence, chain of thought context accuracy, and relevance of the model return based on the three different RAG methods. Each of these methods were evaluated by a an evaluation model that scored the RAG response based on how relevant/close it was to the expected output from the dataset.
